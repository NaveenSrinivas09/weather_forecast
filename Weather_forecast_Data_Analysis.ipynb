# %% [markdown]
# <a href="https://colab.research.google.com/github/NaveenSrinivas09/weather_forecast/blob/main/Weather_forecast_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import kaggle
# kaggle competitions download -c dogs-vs-cats
#
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/sample_data/seattle-weather.csv')

# %%
df.head(5)
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
df.shape
# Out:
# (1461, 6)

# %%
df.columns
# Out:
# Index(['date', 'precipitation', 'temp_max', 'temp_min', 'wind', 'weather'], dtype='object')

# %%
df.dtypes
# Out:
# date              object
# precipitation    float64
# temp_max         float64
# temp_min         float64
# wind             float64
# weather           object
# dtype: object

# %%
# df.describe()
df['date'].unique()
# Out:
# array(['2012-01-01', '2012-01-02', '2012-01-03', ..., '2015-12-29',
#        '2015-12-30', '2015-12-31'], dtype=object)

# %%
df.nunique()
# Out:
# date             1461
# precipitation     111
# temp_max           67
# temp_min           55
# wind               79
# weather             5
# dtype: int64

# %%
df.count()
# Out:
# date             1461
# precipitation    1461
# temp_max         1461
# temp_min         1461
# wind             1461
# weather          1461
# dtype: int64

# %%
df['weather'].value_counts()
# Out:
# weather
# rain       641
# sun        640
# fog        101
# drizzle     53
# snow        26
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1461 non-null   object
#  1   precipitation  1461 non-null   float64
#  2   temp_max       1461 non-null   float64
#  3   temp_min       1461 non-null   float64
#  4   wind           1461 non-null   float64
#  5   weather        1461 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 68.6+ KB

# %%
df.head()
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain

# %% [markdown]
# Q1. find all unique wind speed in data

# %%
df['wind'].nunique()
# Out:
# 79

# %%
df.nunique()
# Out:
# date             1461
# precipitation     111
# temp_max           67
# temp_min           55
# wind               79
# weather             5
# dtype: int64

# %%
df['weather'].unique()
# Out:
# array(['drizzle', 'rain', 'sun', 'snow', 'fog'], dtype=object)

# %%
df.weather.value_counts()
# Out:
# weather
# rain       641
# sun        640
# fog        101
# drizzle     53
# snow        26
# Name: count, dtype: int64

# %%
# df[df.weather =='snow'].head()
df.groupby('weather').get_group('snow').head()
# Out:
#           date  precipitation  temp_max  temp_min  wind weather
# 13  2012-01-14            4.1       4.4       0.6   5.3    snow
# 14  2012-01-15            5.3       1.1      -3.3   3.2    snow
# 15  2012-01-16            2.5       1.7      -2.8   5.0    snow
# 16  2012-01-17            8.1       3.3       0.0   5.6    snow
# 17  2012-01-18           19.8       0.0      -2.8   5.0    snow

# %%
df[df['wind']<=5]
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1     2012-01-02           10.9      10.6       2.8   4.5     rain
# 2     2012-01-03            0.8      11.7       7.2   2.3     rain
# 3     2012-01-04           20.3      12.2       5.6   4.7     rain
# 5     2012-01-06            2.5       4.4       2.2   2.2     rain
# ...          ...            ...       ...       ...   ...      ...
# 1456  2015-12-27            8.6       4.4       1.7   2.9     rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3     rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1287 rows x 6 columns]

# %%
df[df['wind']<=5]['weather'].value_counts()
# Out:
# weather
# sun        602
# rain       521
# fog         96
# drizzle     53
# snow        15
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# date             0
# precipitation    0
# temp_max         0
# temp_min         0
# wind             0
# weather          0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# date             1461
# precipitation    1461
# temp_max         1461
# temp_min         1461
# wind             1461
# weather          1461
# dtype: int64

# %%
df.rename(columns={'weather':'weather_condition'},inplace=True)
df.head(1)
# Out:
#          date  precipitation  temp_max  temp_min  wind weather_condition
# 0  2012-01-01            0.0      12.8       5.0   4.7           drizzle

# %%
df.head(2)
# Out:
#          date  precipitation  temp_max  temp_min  wind weather_condition
# 0  2012-01-01            0.0      12.8       5.0   4.7           drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5              rain

# %%
df.precipitation.mean().round(2)
# Out:
# 3.03

# %%
# df.precipitation.max()
df.precipitation.std()
# Out:
# 6.680194322314738
